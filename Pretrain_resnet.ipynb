# %%
from pretrain_resnet_tagger import *
torch.cuda.empty_cache()
e = Experiment('pretrain_resnet_tagger', verbose_freq = 50)
# train the fully connected layer for 3 pochs
# then train entire model
#e.run()
test_loss, eval_= e.test()
torch.cuda.empty_cache()
# Out:
# Using the saved vocab.
# /opt/conda/lib/python3.9/site-packages/torchvision/transforms/transforms.py:280: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# start trainingin entire network
# training on cuda:0
# /opt/conda/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# batch0, 0.012487809173762798
# batch50, 0.011762430891394615
# batch100, 0.012592083774507046
# batch150, 0.010970864444971085
# batch200, 0.012153556570410728
# epoch 7, train:0.01208212830205547, val:0.013346610590815544
# ...

# %%
from pretrain_resnet_tagger import *
torch.cuda.empty_cache()
e = Experiment('pretrain_resnet_tagger-fc2', verbose_freq = 50)
# train the fully connected layer for 3 pochs
# then train entire model
e.run()
test_loss, eval_= e.test()
torch.cuda.empty_cache()
# Out:
# Using the saved vocab.
# 2 fully connected lyr
# training on cuda:0
# /opt/conda/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# batch0, 0.6995985507965088
# batch50, 0.023683149367570877
# batch100, 0.017650075256824493
# batch150, 0.014500786550343037
# batch200, 0.015220096334815025
# epoch 0, train:0.02699004722402451, val:0.014460139672118651
# Epoch: 1, Train Loss: 0.02699004722402451, Val Loss: 0.014460139672118651, Took 0:33:33.006633, ETA: 6:42:36.079596
#
# training on cuda:0
# batch0, 0.013871433213353157
# batch50, 0.014798841439187527
# batch150, 0.013925330713391304
# batch200, 0.014329297468066216
# ...

# %%
import pandas as pd
eval_12 = pd.read_csv('experiment_data/ResNet-tagger/cls_eval_12.csv', index_col = 0)
eval_12_fc2 = pd.read_csv('experiment_data/ResNet-tagger-fc2/cls_eval_12.csv', index_col = 0)

# %%
m = eval_12.merge(eval_12_fc2, left_index = True, right_index = True, suffixes = ('_fc1', '_fc2'))
m.plot.scatter(x='f1_fc1', y='f1_fc2', figsize = (4,4))
# Out:
# <AxesSubplot:xlabel='f1_fc1', ylabel='f1_fc2'>

# %%
from pretrain_resnet_embed import *
torch.cuda.empty_cache()
model = ResNet_attention()
e = Experiment('pretrain_resnet_embedder', model, verbose_freq = 50)
# train the fully connected layer for 3 pochs
# then train entire model
e.run()
test_loss, eval_= e.test()
torch.cuda.empty_cache()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /tmp/xdg-cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Using the saved vocab.
# /opt/conda/lib/python3.9/site-packages/torchvision/transforms/transforms.py:280: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# start trainingin entire network
# training on cuda:0
# /opt/conda/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# batch0, 4.1370316239408567e-07
# batch50, 2.2436623225985386e-07
# batch100, 4.2645001485652756e-07
# ...

# %%
from pretrain_resnet_embed import *
torch.cuda.empty_cache()
model = ResNet_attention(n_lyr=2)
e = Experiment('pretrain_resnet_embedder-fc2', model, verbose_freq = 50)
# train the fully connected layer for 3 pochs
# then train entire model
e.run()
test_loss, eval_= e.test()
torch.cuda.empty_cache()
# Out:
# Using the saved vocab.
# /opt/conda/lib/python3.9/site-packages/torchvision/transforms/transforms.py:280: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# training on cuda:0
# /opt/conda/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# batch0, 0.003841632744297385
# batch50, 0.000295965961413458
# batch100, 0.00017636209668125957
# batch150, 0.00010307883349014446
# batch200, 6.0455706261564046e-05
# epoch 0, train:0.0003016551155095395, val:5.473456856841811e-05
# ...
